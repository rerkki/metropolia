# %% [markdown]
# Ladataan tarvittavat kirjastot:
#
# > pandas; matematiikkakirjasto - https://pandas.pydata.org/
#
# > numpy; toinen matematiikkakirjasto - https://numpy.org/doc/
#
# > matplotlib; visualisointikirjasto - https://matplotlib.org/
#
# > seaborn; visualisointikirjasto - https://seaborn.pydata.org/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dat = pd.read_csv("https://raw.githubusercontent.com/rerkki/metropolia/master/esimerkkikysely2.csv", encoding='latin-1')

dat[0:10] #tulostetaan otsikko ja ensimmäinen rivi tarkistuksen vuoksi
# Out:
#   Aikaleima  kayttaja  ...  Nukuin viime yon surkeasti  Haluaisin vaihtaa alaa
# 0  7.6.2020    123098  ...                           4                       2
# 1  7.6.2020     98123  ...                           4                       5
# 2  7.6.2020    234789  ...                           1                       2
# 3  7.6.2020    345876  ...                           2                       2
# 4  7.6.2020    543567  ...                           4                       5
# 5  7.6.2020    333666  ...                           2                       3
# 6  7.6.2020    678876  ...                           3                       2
# 7  7.6.2020    999777  ...                           5                       4
# 8  8.6.2020    123098  ...                           1                       2
# 9  8.6.2020     98123  ...                           5                       4
#
# [10 rows x 8 columns]

# %%
dat2 = dat.rename(columns={'Tanaan herasin taynna energiaa': 'K1', 
                      'Minulla on suunnitelmia ensi viikonlopulle': 'K2',
                      'Olen liikkunut tanaan riittavasti': 'K3',
                      'Aion olla hyvassa kunnossa ensi kesana': 'K4',
                      'Nukuin viime yon surkeasti': 'K5',
                      'Haluaisin vaihtaa alaa': 'K6'})

dat2[0:10] #tulostetaan otsikko ja ensimmäinen rivi tarkistuksen vuoksi
# Out:
#   Aikaleima  kayttaja  K1  K2  K3  K4  K5  K6
# 0  7.6.2020    123098   3   5   4   3   4   2
# 1  7.6.2020     98123   1   2   2   1   4   5
# 2  7.6.2020    234789   5   4   5   5   1   2
# 3  7.6.2020    345876   3   4   3   3   2   2
# 4  7.6.2020    543567   4   5   3   4   4   5
# 5  7.6.2020    333666   3   4   4   3   2   3
# 6  7.6.2020    678876   2   3   1   3   3   2
# 7  7.6.2020    999777   2   1   2   2   5   4
# 8  8.6.2020    123098   2   5   4   4   1   2
# 9  8.6.2020     98123   4   2   4   3   5   4

# %%
sns.set(style="whitegrid", rc={'figure.figsize':(16,8)})

ax = sns.barplot(x=dat.kayttaja, y=dat2.K1, data=dat2)

# %%
sns.set(style="whitegrid", rc={'figure.figsize':(24,8)})

fig, ax =plt.subplots(1,2)
sns.lineplot(x=dat.Aikaleima, y=dat2.K1, data=dat2, ax = ax[0])
sns.lineplot(x= dat.index, y=dat2.K1, data=dat2, ax = ax[1])

fig.show()

# %%
dat = dat2[['K1', 'K2', 'K3', 'K4', 'K5', 'K6']]

corr = dat.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.pairplot(dat2, corner = True)
